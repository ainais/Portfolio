# %%
# Practicing Class and Function
class Contact:
    def __init__(self, name, phone_number, email, addr):
        self.name=name
        self.phone_name=phone_number
        self.email=email
        self.addr=addr

    def print_info(self):
        print("이름:", self.name)
        print("전화번호:", self.phone_name)
        print("이메일:", self.email)
        print("주소;", self.addr+'\n')
#==============================================================
def print_menu():
    print('1. 연락처 입력')
    print('2. 연락처 출력')
    print('3. 연락처 삭제')
    print('4. 종료 \n')
    menu=input('메뉴선택:')
    return int(menu)

def set_contact():
    name=input('이름은?')
    phone_number=input('전화번호는?')
    email=input('이메일은?')
    addr=input('주소는?')
    return Contact(name,phone_number,email,addr)

def print_contact(contact_list):
    if len(contact_list) == 0 :
        print('입력된 정보가 없습니다.\n')
    else:
        print('\nwwwwwww정보출력시작wwwwwww')
        print('------------------')
        for i in contact_list:
            print(i.name+'님의 정보입니다.')
            i.print_info()
            print('------------------')
        print('wwwwwww정보출력종료wwwwwww\n')

def delete_contact(contact_list, name):
    print('\nwwwwwww삭제 시작wwwwwww')
    cnt = 0
    for i in contact_list:
        if i.name == name:
            contact_list.remove(i)
            cnt += 1
            print('삭제가 완료되었습니다. \n')
            break
    if cnt == 0:
        print('존재하지 않는 회원입니다.')
    print('wwwwwww삭제 종료wwwwwww\n')

def run():
    # Contact 인스턴스를 저장할 리스트 자료구조 생성
    contact_list = []
    while True:
        menu=print_menu()
        if menu==4:  # 종료를 선택하면
            break
        elif menu==1: # 입력을 선택하면
            contact = set_contact()
            contact_list.append(contact)
        elif menu==2: # 출력을 선택하면
            print_contact(contact_list)
        elif menu==3: # 삭제를 선택하면
            name = input('삭제할 이름은?')
            delete_contact(contact_list,name)
        else:
            print('숫자가 아닌 다른 문자는 입력할 수 없습니다.')

if __name__ == "__main__":
    run()
# Out:
# 1. 연락처 입력
# 2. 연락처 출력
# 3. 연락처 삭제
# 4. 종료
#
# 메뉴선택:1
# 이름은?이정성
# 전화번호는?010
# 이메일은?kou
# 주소는?가산동
# 1. 연락처 입력
# 2. 연락처 출력
# 3. 연락처 삭제
# 4. 종료
#
# 메뉴선택:2
#
# wwwwwww정보출력시작wwwwwww
# ------------------
# 이정성님의 정보입니다.
# 이름: 이정성
# 전화번호: 010
# 이메일: kou
# 주소; 가산동
#
# ------------------
# wwwwwww정보출력종료wwwwwww
#
# 1. 연락처 입력
# 2. 연락처 출력
# 3. 연락처 삭제
# 4. 종료
#
# 메뉴선택:3
# 삭제할 이름은?이정성
#
# wwwwwww삭제 시작wwwwwww
# 삭제가 완료되었습니다.
#
# wwwwwww삭제 종료wwwwwww
#
# 1. 연락처 입력
# 2. 연락처 출력
# 3. 연락처 삭제
# 4. 종료
#
# 메뉴선택:4
